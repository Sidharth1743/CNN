# %% [markdown]
# <a href="https://colab.research.google.com/github/Sidharth1743/CNN/blob/main/Image_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget 'https://tractive.com/blog/wp-content/uploads/2021/11/AdobeStock_165815472-1.jpeg'
# Out:
# --2024-08-10 09:41:45--  https://tractive.com/blog/wp-content/uploads/2021/11/AdobeStock_165815472-1.jpeg
# Resolving tractive.com (tractive.com)... 3.163.165.81, 3.163.165.88, 3.163.165.72, ...
# Connecting to tractive.com (tractive.com)|3.163.165.81|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 219019 (214K) [image/jpeg]
# Saving to: ‘AdobeStock_165815472-1.jpeg’
#
# AdobeStock_16581547 100%[===================>] 213.89K   504KB/s    in 0.4s
#
# 2024-08-10 09:41:46 (504 KB/s) - ‘AdobeStock_165815472-1.jpeg’ saved [219019/219019]

# %%
import matplotlib.image as img
import matplotlib.pyplot as plt
imag=img.imread('/content/AdobeStock_165815472-1.jpeg')
plt.imshow(imag)
print(imag.shape)
# Out:
# (1280, 1913, 3)

# %%
from PIL import Image
img=Image.open('/content/AdobeStock_165815472-1.jpeg')
resized_image=img.resize((200,200))
resized_image=resized_image.save('sample_image.jpg')

# %%
import matplotlib.image as img
res_image=img.imread('/content/sample_image.jpg')
plt.imshow(res_image)
print(res_image.shape)
# Out:
# (200, 200, 3)

# %%
import cv2
image=cv2.imread('/content/sample_image.jpg')
plt.imshow(image)
convert=cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)
convert.shape
# Out:
# (200, 200)

# %%
plt.imshow(convert)

# %%
save=cv2.imwrite('Grayscale image.jpg',convert)
